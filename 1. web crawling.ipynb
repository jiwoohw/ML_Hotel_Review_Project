# %%
# 모듈

from selenium import webdriver
from selenium.webdriver.common.action_chains import ActionChains
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup
from urllib.request import urlopen, Request
import time
from tqdm.notebook import tqdm_notebook
from selenium.common.exceptions import NoSuchElementException

# %%
#비상 종료용
driver.close()
# Out:
#   Cell In[31], line 2
#     python setup.py install
#            ^
# SyntaxError: invalid syntax

# %%
#호텔 리스트
jeju_five_stars = ['메종글래드 제주', '그랜드하얏트제주', '그랜드조선 제주',  '제주 신라 호텔', '제주 오리엔탈 호텔 앤 카지노', '서귀포 칼 호텔', ' 스위트 호텔 제주', '제주 부영호텔&리조트', '씨에스호텔앤리조트', '라마다프라자제주호텔',
              '롯데호텔 제주', '제주신화월드 호텔 앤 리조트', '그랜드하얏트제주', '히든 클리프 호텔 앤 네이처 제주', '위 호텔 제주', '해비치 호텔 앤 리조트 제주',
              '파르나스호텔 제주']

jeju_four_stars = ['아스타호텔 제주', '호텔시리우스 제주', '다인오세아노호텔 제주', '그라벨 호텔 제주', '호텔빠레브 제주', '골드윈 호텔 앤 스위트',
                   '플레이스 제주', '호텔 난타 제주', '호텔 더본 제주', '제주 퍼시픽 호텔']

jeju_three_stars = ['호텔 스카이파크 제주', '제주 갤럭시 호텔', '아이진 호텔 제주', '메이더 호텔 제주', '유어스 호텔 제주', '어반 아일랜드 호텔 제주', '스타즈호텔 제주 로베로',
                    '블랙샌즈호텔 제주', '블루마운틴호텔 제주', '파크선샤인호텔 제주', '호텔 아루미 제주', '베니키아 중문호텔 제주', '라온 호텔 앤 리조트 제주', '오드리인 제주',
                    '오션그랜드호텔 제주', '까사로마 호텔 제주', '애월비치호텔 제주', '팔레스호텔 제주', '베니키아호텔 제주']

jeju_two_stars = ['하버호텔 제주', '더스테이센추리 호텔 제주', '시티홀 호텔 제주', '라관광 제주', '호텔 캘리포니아 제주', '로긴 호텔 제주', '호텔 컬리넌 제주']

jeju_one_stars = ['리시온 호텔 제주', 'CJ관광호텔 제주', '골든파크호텔 제주']

# %%
print()
# Out:
# 3

# %%
url = "https://www.agoda.com/ko-kr/search?city=16901&checkIn=2023-03-14&los=1&rooms=1&adults=2&children=0&locale=ko-kr&ckuid=86468870-1199-48cf-8d7b-22f848460a09&prid=0&gclid=Cj0KCQiA9YugBhCZARIsAACXxeL-x6SAeq9oNwlH4uSDat4ghNHjB9r0nPykHqgrsO8mxWTSTj5xpowaAuVIEALw_wcB&currency=KRW&correlationId=4504de2c-1017-4434-a938-bd9cf2945fa3&analyticsSessionId=-1205114080302989865&pageTypeId=5&realLanguageId=9&languageId=9&origin=KR&cid=1891442&tag=76904620-46e3-4a79-af71-f452e5c6d44b&userId=86468870-1199-48cf-8d7b-22f848460a09&whitelabelid=1&loginLvl=0&storefrontId=3&currencyId=26&currencyCode=KRW&htmlLanguage=ko-kr&cultureInfoName=ko-kr&machineName=hk-geoweb-2003&trafficGroupId=5&sessionId=pit3rf141nnpbbe0t1baekln&trafficSubGroupId=9&aid=82361&useFullPageLogin=true&cttp=4&isRealUser=true&mode=production&browserFamily=Chrome&checkOut=2023-03-15&priceCur=KRW&textToSearch=%EC%A0%9C%EC%A3%BC&travellerType=1&familyMode=off&hotelStarRating=5&productType=-1"
driver = webdriver.Chrome("../../../Documents/ds_study/driver/chromedriver.exe") 
driver.get(url)
datas = []
for num in tqdm_notebook(range(0, len(jeju_one_stars))): #호텔 등급따라 수정
    # 검색 입력 과정
    time.sleep(3)
    path_one = '//*[@id="autocomplete-box"]/div'
    tag_one = driver.find_element_by_xpath(path_one)
    tag_one.click()
    time.sleep(3)
    search_path = 'textInput'
    some_tag = driver.find_element_by_id(search_path)
    some_tag.clear()
    some_tag.click()
    # 호텔명 입력하기 1
    some_tag.send_keys(jeju_one_stars[num])  #호텔 등급따라 수정
    time.sleep(3)
    # 호텔명 입력하기 2
    click_path1 = '//*[@id="SearchBoxContainer"]/div/div/div[5]/div/div/ul/li[1]'
    click_tag1 = driver.find_element_by_xpath(click_path1).click()
    time.sleep(3)
    # 호텔 검색하기
    click_path2 = '//*[@id="SearchBoxContainer"]/div/div/button'
    click_tag2 = driver.find_element_by_xpath(click_path2).click()
    time.sleep(10.0)
    # 호텔 클릭하기
    try:
        hotel_path = '//*[@id="contentContainer"]/div[4]/ol/li[1]/div[2]/a/div/div[3]/div/div[1]'
        click_tag3 = driver.find_element_by_xpath(hotel_path).click()

    except NoSuchElementException:
        hotel_path = '//*[@id="contentContainer"]/div[5]/ol/li[1]/div[2]/a/div/div[3]/div/div[1]'
        click_tag3 = driver.find_element_by_xpath(hotel_path).click()
    # 각 호텔 페이지로 전환
    driver.switch_to_window(driver.window_handles[1])
 
    time.sleep(5)
    
    try :
        page_tmp=driver.find_element_by_xpath('//*[@id="reviewSection"]/div[4]/div/span[3]')
        page_click=driver.find_element_by_css_selector('#reviewSection > div:nth-child(4) > div > span:nth-child(3) > i')
        pop = driver.find_element_by_css_selector('div.StickyFooter > div')
        pop_del = driver.find_element_by_xpath('//*[@id="dismiss-btn"]')
    except :
        page_tmp= 0
        pop = driver.find_element_by_css_selector('div.StickyFooter > div')
        pop_del = driver.find_element_by_xpath('//*[@id="dismiss-btn"]')
        
    #리뷰 크롤링 시작
    while page_tmp == 0 or page_tmp.get_attribute('aria-disabled')=='false' :
        time.sleep(2)
        
        #단일 페이지일 경우 확인
        if page_tmp == 0:
            break

        #팝업 제거
        if pop.get_attribute('class') == "BackToSearch" :
            pass
        else: 
            pop_del.click()
        hotel = driver.find_element_by_css_selector('div.Box-sc-kv6pi1-0.cJiLOx.sc-khAkjo.fLpsks > div.HeaderCerebrum > div:nth-child(1)').text.split('\n')[0]
        
        #페이지내 리뷰 저장
        for num in range(len(driver.find_elements_by_class_name('Review-comment'))):
            
            review_data = driver.find_element_by_css_selector("#review-{} > div.Review-comment-left > div".format(num))
            if len(review_data.find_elements_by_class_name('Review-comment-reviewer'))==4:            
                point = driver.find_element_by_css_selector("#review-{} > div.Review-comment-left > div > div.Review-comment-leftHeader > div.Review-comment-leftScore".format(num)).text
                country = driver.find_element_by_css_selector("#review-{} > div.Review-comment-left > div > div:nth-child(2)".format(num)).text
                member = driver.find_element_by_css_selector("#review-{} > div.Review-comment-left > div > div:nth-child(3) > span".format(num)).text
                room = driver.find_element_by_css_selector("#review-{} > div.Review-comment-left > div > div:nth-child(4)".format(num)).text
                day = driver.find_element_by_css_selector("#review-{} > div.Review-comment-left > div > div:nth-child(5)".format(num)).text
                title = driver.find_element_by_css_selector("#review-{} > div.Review-comment-right > div.Review-comment-bubble > div.Review-comment-body".format(num)).text.split('\n')[0][:-1]
                content = driver.find_element_by_css_selector("#review-{} > div.Review-comment-right > div.Review-comment-bubble > div.Review-comment-body".format(num)).text.split('\n')[1:]
                datas.append({'Hotel': hotel,
                            'Point': point,
                            'Country': country,
                            'member' : member,
                            'Room type' : room,
                            'Date' : day,
                            'Review Title' : title,
                            'Review Contents' : content
                                })
            elif len(review_data.find_elements_by_class_name('Review-comment-reviewer'))==3:
                point = driver.find_element_by_css_selector("#review-{} > div.Review-comment-left > div > div:nth-child(1)".format(num)).text
                country = driver.find_element_by_css_selector("#review-{} > div.Review-comment-left > div > div:nth-child(2)".format(num)).text
                member = driver.find_element_by_css_selector("#review-{} > div.Review-comment-left > div > div:nth-child(3) > span".format(num)).text
                room = "객실정보없음"
                day = driver.find_element_by_css_selector("#review-{} > div.Review-comment-left > div > div:nth-child(4)".format(num)).text
                title = driver.find_element_by_css_selector("#review-{} > div.Review-comment-right > div.Review-comment-bubble > div.Review-comment-body".format(num)).text.split('\n')[0][:-1]
                content = driver.find_element_by_css_selector("#review-{} > div.Review-comment-right > div.Review-comment-bubble > div.Review-comment-body".format(num)).text.split('\n')[1:]
                datas.append({'Hotel': hotel,
                            'Point': point,
                            'Country': country,
                            'member' : member,
                            'Room type' : room,
                            'Date' : day,
                            'Review Title' : title,
                            'Review Contents' : content
                                })
            else:
                pass
        #다음페이지 넘어가기
        page_click.click()

    #마지막페이지 리뷰 크롤링
    for num in range(len(driver.find_elements_by_class_name('Review-comment'))):
    
        review_data = driver.find_element_by_css_selector("#review-{} > div.Review-comment-left > div".format(num))
        if len(review_data.find_elements_by_class_name('Review-comment-reviewer'))==4:            
            point = driver.find_element_by_css_selector("#review-{} > div.Review-comment-left > div > div.Review-comment-leftHeader > div.Review-comment-leftScore".format(num)).text
            country = driver.find_element_by_css_selector("#review-{} > div.Review-comment-left > div > div:nth-child(2)".format(num)).text
            member = driver.find_element_by_css_selector("#review-{} > div.Review-comment-left > div > div:nth-child(3) > span".format(num)).text
            room = driver.find_element_by_css_selector("#review-{} > div.Review-comment-left > div > div:nth-child(4)".format(num)).text
            day = driver.find_element_by_css_selector("#review-{} > div.Review-comment-left > div > div:nth-child(5)".format(num)).text
            title = driver.find_element_by_css_selector("#review-{} > div.Review-comment-right > div.Review-comment-bubble > div.Review-comment-body".format(num)).text.split('\n')[0][:-1]
            content = driver.find_element_by_css_selector("#review-{} > div.Review-comment-right > div.Review-comment-bubble > div.Review-comment-body".format(num)).text.split('\n')[1:]
            datas.append({'Hotel': hotel,
                        'Point': point,
                        'Country': country,
                        'member' : member,
                        'Room type' : room,
                        'Date' : day,
                        'Review Title' : title,
                        'Review Contents' : content
                            })
        elif len(review_data.find_elements_by_class_name('Review-comment-reviewer'))==3:
            point = driver.find_element_by_css_selector("#review-{} > div.Review-comment-left > div > div:nth-child(1)".format(num)).text
            country = driver.find_element_by_css_selector("#review-{} > div.Review-comment-left > div > div:nth-child(2)".format(num)).text
            member = driver.find_element_by_css_selector("#review-{} > div.Review-comment-left > div > div:nth-child(3) > span".format(num)).text
            room = "객실정보없음"
            day = driver.find_element_by_css_selector("#review-{} > div.Review-comment-left > div > div:nth-child(4)".format(num)).text
            title = driver.find_element_by_css_selector("#review-{} > div.Review-comment-right > div.Review-comment-bubble > div.Review-comment-body".format(num)).text.split('\n')[0][:-1]
            content = driver.find_element_by_css_selector("#review-{} > div.Review-comment-right > div.Review-comment-bubble > div.Review-comment-body".format(num)).text.split('\n')[1:]
            datas.append({'Hotel': hotel,
                        'Point': point,
                        'Country': country,
                        'member' : member,
                        'Room type' : room,
                        'Date' : day,
                        'Review Title' : title,
                        'Review Contents' : content
                            })
        else:
            pass
    driver.close()
    time.sleep(0.5)
    driver.switch_to_window(driver.window_handles[0])     
df =pd.DataFrame(datas)
df.to_csv('./hotel1_review.csv')  #호텔 등급따라 파일명 수정
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# C:\Users\지우\AppData\Local\Temp\ipykernel_20212\1389451521.py:36: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[1])
# C:\Users\지우\AppData\Local\Temp\ipykernel_20212\1389451521.py:150: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[0])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12503 entries, 0 to 12502
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Hotel            12503 non-null  object
#  1   Point            12503 non-null  object
#  2   Country          12503 non-null  object
#  3   member           12503 non-null  object
#  4   Room type        12503 non-null  object
#  5   Date             12503 non-null  object
#  6   Review Title     12503 non-null  object
#  7   Review Contents  12503 non-null  object
# dtypes: object(8)
# memory usage: 781.6+ KB

# %%
df.head()
# Out:
#                           Hotel    Point           Country           member  \
# 0  메종 글래드 제주 (Maison Glad Jeju)     10.0  Seung-hye (대한민국)          나홀로 여행객
# 1  메종 글래드 제주 (Maison Glad Jeju)  10.0 최고  eunkyeong (대한민국)        커플/2인 여행객
# 2  메종 글래드 제주 (Maison Glad Jeju)     10.0       moon (대한민국)        커플/2인 여행객
# 3  메종 글래드 제주 (Maison Glad Jeju)     10.0  Kyungsoon (대한민국)  유아/아동 동반 가족 여행객
# 4  메종 글래드 제주 (Maison Glad Jeju)     10.0   Gyucheol (대한민국)        커플/2인 여행객
#
#   Room type           Date           Review Title  \
# 0   스탠다드 트윈  2021년 5월 | 3박              기대보다 좋았어요
# 1    객실정보없음  2019년 8월 | 1박                수영장이용!!
# 2   프리미엄 더블  2021년 4월 | 1박         메종 글래드 너무 좋았어요
# 3   스탠다드 트윈  2021년 3월 | 1박  5성급 호텔을 저렴한가격에 누릴수있는곳
# 4   스탠다드 트윈  2021년 2월 | 2박          4계절이 다른 도심속호텔
#
#                                      Review Contents
# 0  [시설이 낡았다는 후기를 보고 별 기대없이 갔는데 3박동안 행복하게 보내고 왔습니다...
# 1  [첫날 공항이랑 가까워서 이용했구요 수영장이 화면보다 작아요 많이 수영장보고 선택한...
# ...

# %%
df.to_csv('./hotel5_review.csv',encoding='utf-8')

# %%
df5=pd.read_csv('./hotel5_review.csv')
df5.tail()
# Out:
#        Unnamed: 0                           Hotel Point          Country  \
# 15530       15530  파르나스 호텔 제주 (PARNAS HOTEL JEJU)  10.0      Dong (대한민국)
# 15531       15531  파르나스 호텔 제주 (PARNAS HOTEL JEJU)  10.0   daesung (대한민국)
# 15532       15532  파르나스 호텔 제주 (PARNAS HOTEL JEJU)  10.0  Youngsoo (대한민국)
# 15533       15533  파르나스 호텔 제주 (PARNAS HOTEL JEJU)   9.6     Trenton (미국)
# 15534       15534  파르나스 호텔 제주 (PARNAS HOTEL JEJU)  10.0    Jihoon (대한민국)
#
#                 member     Room type           Date          Review Title  \
# 15530  유아/아동 동반 가족 여행객  프리미어 패밀리 트윈룸  2022년 9월 | 1박               깨끗하고 편안
# 15531          나홀로 여행객         디럭스 킹  2022년 9월 | 1박           제주도 경관 No.1
# 15532    청소년 동반 가족 여행객  프리미어 패밀리 트윈룸  2022년 8월 | 1박                   수영장
# 15533          나홀로 여행객    디럭스 패밀리 트윈  2023년 2월 | 3박  Great Place to Relax
# 15534  유아/아동 동반 가족 여행객         디럭스 킹  2023년 1월 | 1박      Great facilities
#
#                                          Review Contents
# ...

# %%
#테스트용

url = "https://www.agoda.com/ko-kr/search?city=16901&checkIn=2023-03-14&los=1&rooms=1&adults=2&children=0&locale=ko-kr&ckuid=86468870-1199-48cf-8d7b-22f848460a09&prid=0&gclid=Cj0KCQiA9YugBhCZARIsAACXxeL-x6SAeq9oNwlH4uSDat4ghNHjB9r0nPykHqgrsO8mxWTSTj5xpowaAuVIEALw_wcB&currency=KRW&correlationId=4504de2c-1017-4434-a938-bd9cf2945fa3&analyticsSessionId=-1205114080302989865&pageTypeId=5&realLanguageId=9&languageId=9&origin=KR&cid=1891442&tag=76904620-46e3-4a79-af71-f452e5c6d44b&userId=86468870-1199-48cf-8d7b-22f848460a09&whitelabelid=1&loginLvl=0&storefrontId=3&currencyId=26&currencyCode=KRW&htmlLanguage=ko-kr&cultureInfoName=ko-kr&machineName=hk-geoweb-2003&trafficGroupId=5&sessionId=pit3rf141nnpbbe0t1baekln&trafficSubGroupId=9&aid=82361&useFullPageLogin=true&cttp=4&isRealUser=true&mode=production&browserFamily=Chrome&checkOut=2023-03-15&priceCur=KRW&textToSearch=%EC%A0%9C%EC%A3%BC&travellerType=1&familyMode=off&hotelStarRating=5&productType=-1"
driver = webdriver.Chrome("../driver/chromedriver") 
driver.get(url)

for num in tqdm_notebook(range(0, 1)): #호텔 등급따라 수정
    # 검색 입력 과정
    time.sleep(3)
    path_one = '//*[@id="autocomplete-box"]/div'
    tag_one = driver.find_element_by_xpath(path_one)
    tag_one.click()
    time.sleep(3)
    search_path = 'textInput'
    some_tag = driver.find_element_by_id(search_path)
    some_tag.clear()
    some_tag.click()
    # 호텔명 입력하기 1
    some_tag.send_keys(jeju_five_stars[num])
    time.sleep(3)
    # 호텔명 입력하기 2
    click_path1 = '//*[@id="SearchBoxContainer"]/div/div/div[5]/div/div/ul/li[1]'
    click_tag1 = driver.find_element_by_xpath(click_path1).click()
    time.sleep(3)
    # 호텔 검색하기
    click_path2 = '//*[@id="SearchBoxContainer"]/div/div/button'
    click_tag2 = driver.find_element_by_xpath(click_path2).click()
    time.sleep(8.0)
    # 호텔 클릭하기
    hotel_path = '#contentContainer > div:nth-child(4) > ol > li:nth-child(1) > div.Box-sc-kv6pi1-0.hRUYUu.JacketContent.JacketContent--SelectedProperty > a > div > div.Itemstyled__Item-sc-12uga7p-0.cNsNca.PropertyCard__Section.PropertyCard__Section--pricingInfo > div > div.Box-sc-kv6pi1-0.hRUYUu.PropertyCard__PricingHeadliner'
    click_tag3 = driver.find_element_by_css_selector(hotel_path).click()
    # 각 호텔 페이지로 전환
    driver.switch_to_window(driver.window_handles[1])
 
    time.sleep(5)
    datas = []
    page_tmp=driver.find_element_by_xpath('//*[@id="reviewSection"]/div[4]/div/span[3]')
    page_click=driver.find_element_by_css_selector('#reviewSection > div:nth-child(4) > div > span:nth-child(3) > i')
    pop = driver.find_element_by_css_selector('div.StickyFooter > div')
    pop_del = driver.find_element_by_xpath('//*[@id="dismiss-btn"]')

    #리뷰 크롤링 시작
    for x in range(2):
    # while page_tmp.get_attribute('aria-disabled')=='false' :
        time.sleep(2)
        #팝업 제거
        if pop.get_attribute('class') == "BackToSearch" :
            pass
        else: 
            pop_del.click()
        hotel = driver.find_element_by_css_selector('div.Box-sc-kv6pi1-0.cJiLOx.sc-khAkjo.fLpsks > div.HeaderCerebrum > div:nth-child(1)').text.split('\n')[0]
        #페이지내 리뷰 저장
        for num in range(len(driver.find_elements_by_class_name('Review-comment'))):
            
            review_data = driver.find_element_by_css_selector("#review-{} > div.Review-comment-left > div".format(num))
            if len(review_data.find_elements_by_class_name('Review-comment-reviewer'))==4:            
                point = driver.find_element_by_css_selector("#review-{} > div.Review-comment-left > div > div.Review-comment-leftHeader > div.Review-comment-leftScore".format(num)).text
                country = driver.find_element_by_css_selector("#review-{} > div.Review-comment-left > div > div:nth-child(2)".format(num)).text
                member = driver.find_element_by_css_selector("#review-{} > div.Review-comment-left > div > div:nth-child(3) > span".format(num)).text
                room = driver.find_element_by_css_selector("#review-{} > div.Review-comment-left > div > div:nth-child(4)".format(num)).text
                day = driver.find_element_by_css_selector("#review-{} > div.Review-comment-left > div > div:nth-child(5)".format(num)).text
                title = driver.find_element_by_css_selector("#review-{} > div.Review-comment-right > div.Review-comment-bubble > div.Review-comment-body".format(num)).text.split('\n')[0][:-1]
                content = driver.find_element_by_css_selector("#review-{} > div.Review-comment-right > div.Review-comment-bubble > div.Review-comment-body".format(num)).text.split('\n')[1:]
                datas.append({'Hotel': hotel,
                            'Point': point,
                            'Country': country,
                            'member' : member,
                            'Room type' : room,
                            'Date' : day,
                            'Review Title' : title,
                            'Review Contents' : content
                                })
            elif len(review_data.find_elements_by_class_name('Review-comment-reviewer'))==3:
                point = driver.find_element_by_css_selector("#review-{} > div.Review-comment-left > div > div:nth-child(1)".format(num)).text
                country = driver.find_element_by_css_selector("#review-{} > div.Review-comment-left > div > div:nth-child(2)".format(num)).text
                member = driver.find_element_by_css_selector("#review-{} > div.Review-comment-left > div > div:nth-child(3) > span".format(num)).text
                room = "객실정보없음"
                day = driver.find_element_by_css_selector("#review-{} > div.Review-comment-left > div > div:nth-child(4)".format(num)).text
                title = driver.find_element_by_css_selector("#review-{} > div.Review-comment-right > div.Review-comment-bubble > div.Review-comment-body".format(num)).text.split('\n')[0][:-1]
                content = driver.find_element_by_css_selector("#review-{} > div.Review-comment-right > div.Review-comment-bubble > div.Review-comment-body".format(num)).text.split('\n')[1:]
                datas.append({'Hotel': hotel,
                            'Point': point,
                            'Country': country,
                            'member' : member,
                            'Room type' : room,
                            'Date' : day,
                            'Review Title' : title,
                            'Review Contents' : content
                                })
            else:
                pass
        #다음페이지 넘어가기
        page_click.click()

    #마지막페이지 리뷰 크롤링
    for num in range(len(driver.find_elements_by_class_name('Review-comment'))):
    
        review_data = driver.find_element_by_css_selector("#review-{} > div.Review-comment-left > div".format(num))
        if len(review_data.find_elements_by_class_name('Review-comment-reviewer'))==4:            
            point = driver.find_element_by_css_selector("#review-{} > div.Review-comment-left > div > div.Review-comment-leftHeader > div.Review-comment-leftScore".format(num)).text
            country = driver.find_element_by_css_selector("#review-{} > div.Review-comment-left > div > div:nth-child(2)".format(num)).text
            member = driver.find_element_by_css_selector("#review-{} > div.Review-comment-left > div > div:nth-child(3) > span".format(num)).text
            room = driver.find_element_by_css_selector("#review-{} > div.Review-comment-left > div > div:nth-child(4)".format(num)).text
            day = driver.find_element_by_css_selector("#review-{} > div.Review-comment-left > div > div:nth-child(5)".format(num)).text
            title = driver.find_element_by_css_selector("#review-{} > div.Review-comment-right > div.Review-comment-bubble > div.Review-comment-body".format(num)).text.split('\n')[0][:-1]
            content = driver.find_element_by_css_selector("#review-{} > div.Review-comment-right > div.Review-comment-bubble > div.Review-comment-body".format(num)).text.split('\n')[1:]
            datas.append({'Hotel': hotel,
                        'Point': point,
                        'Country': country,
                        'member' : member,
                        'Room type' : room,
                        'Date' : day,
                        'Review Title' : title,
                        'Review Contents' : content
                            })
        elif len(review_data.find_elements_by_class_name('Review-comment-reviewer'))==3:
            point = driver.find_element_by_css_selector("#review-{} > div.Review-comment-left > div > div:nth-child(1)".format(num)).text
            country = driver.find_element_by_css_selector("#review-{} > div.Review-comment-left > div > div:nth-child(2)".format(num)).text
            member = driver.find_element_by_css_selector("#review-{} > div.Review-comment-left > div > div:nth-child(3) > span".format(num)).text
            room = "객실정보없음"
            day = driver.find_element_by_css_selector("#review-{} > div.Review-comment-left > div > div:nth-child(4)".format(num)).text
            title = driver.find_element_by_css_selector("#review-{} > div.Review-comment-right > div.Review-comment-bubble > div.Review-comment-body".format(num)).text.split('\n')[0][:-1]
            content = driver.find_element_by_css_selector("#review-{} > div.Review-comment-right > div.Review-comment-bubble > div.Review-comment-body".format(num)).text.split('\n')[1:]
            datas.append({'Hotel': hotel,
                        'Point': point,
                        'Country': country,
                        'member' : member,
                        'Room type' : room,
                        'Date' : day,
                        'Review Title' : title,
                        'Review Contents' : content
                            })
        else:
            pass
    driver.close()
    time.sleep(0.5)
    driver.switch_to_window(driver.window_handles[0])    
df =pd.DataFrame(datas)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\Jeong\AppData\Local\Temp\ipykernel_9404\146336259.py:31: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[1])
